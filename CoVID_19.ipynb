# %% [markdown]
# ## COVID 19 Data- from WHO

# %%
import numpy as np
import pandas as pd
import os
import urllib
# %matplotlib inline

# %%
# file path is a variable path for folder in python standard library
url = "https://covid19.who.int/WHO-COVID-19-global-table-data.csv"
file_path = os.path.join("data", "covid")

# %%
# make directories in os filepath
os.makedirs(file_path, exist_ok=True)
csv_path = os.path.join(file_path,"WHO-COVID-19-gloval-data.csv")
urllib.request.urlretrieve(url,csv_path)
# Out:
# ('data\\covid\\WHO-COVID-19-gloval-data.csv',
#  <http.client.HTTPMessage at 0x1774d2f0160>)

# %%
df= pd.read_csv(csv_path)

# %%
df
# Out:
#                                      Name  WHO Region  \
# Global                                NaN   271963258
# United States of America         Americas    49833416
# India                     South-East Asia    34726049
# Brazil                           Americas    22201221
# The United Kingdom                 Europe    11097855
# ...                                   ...         ...
# Pitcairn Islands          Western Pacific           0
# Saint Helena                       Africa           0
# Tokelau                   Western Pacific           0
# Turkmenistan                       Europe           0
# Tuvalu                    Western Pacific           0
#
#                           Cases - cumulative total  \
# Global                                 3489.150681
# United States of America              15055.292000
# India                                  2516.372000
# Brazil                                10444.713000
# The United Kingdom                    16347.781000
# ...

# %%
# restore the row indices

df2=df.reset_index()
df2
# Out:
#                         index             Name  WHO Region  \
# 0                      Global              NaN   271963258
# 1    United States of America         Americas    49833416
# 2                       India  South-East Asia    34726049
# 3                      Brazil         Americas    22201221
# 4          The United Kingdom           Europe    11097855
# ..                        ...              ...         ...
# 233          Pitcairn Islands  Western Pacific           0
# 234              Saint Helena           Africa           0
# 235                   Tokelau  Western Pacific           0
# 236              Turkmenistan           Europe           0
# 237                    Tuvalu  Western Pacific           0
#
#      Cases - cumulative total  Cases - cumulative total per 100000 population  \
# 0                 3489.150681                                         4018879
# 1                15055.292000                                          571461
# ...

# %%
df2.rename(columns={'index': 'country'}, inplace=True)

# %%
df_index = df2.index
df_index
# Out:
# RangeIndex(start=0, stop=238, step=1)

# %%
df_cols = df2.columns
df_cols
# Out:
# Index(['country', 'Name', 'WHO Region', 'Cases - cumulative total',
#        'Cases - cumulative total per 100000 population',
#        'Cases - newly reported in last 7 days',
#        'Cases - newly reported in last 7 days per 100000 population',
#        'Cases - newly reported in last 24 hours', 'Deaths - cumulative total',
#        'Deaths - cumulative total per 100000 population',
#        'Deaths - newly reported in last 7 days',
#        'Deaths - newly reported in last 7 days per 100000 population',
#        'Deaths - newly reported in last 24 hours'],
#       dtype='object')

# %%
df2['country']
# Out:
# 0                        Global
# 1      United States of America
# 2                         India
# 3                        Brazil
# 4            The United Kingdom
#                  ...
# 233            Pitcairn Islands
# 234                Saint Helena
# 235                     Tokelau
# 236                Turkmenistan
# 237                      Tuvalu
# Name: country, Length: 238, dtype: object

# %%
df2.dtypes
# Out:
# country                                                          object
# Name                                                             object
# WHO Region                                                        int64
# Cases - cumulative total                                        float64
# Cases - cumulative total per 100000 population                    int64
# Cases - newly reported in last 7 days                           float64
# Cases - newly reported in last 7 days per 100000 population       int64
# Cases - newly reported in last 24 hours                           int64
# Deaths - cumulative total                                       float64
# Deaths - cumulative total per 100000 population                   int64
# Deaths - newly reported in last 7 days                          float64
# Deaths - newly reported in last 7 days per 100000 population      int64
# Deaths - newly reported in last 24 hours                        float64
# dtype: object

# %%
df2.shape
# Out:
# (238, 13)

# %%
df2.head()
# Out:
#                     country             Name  WHO Region  \
# 0                    Global              NaN   271963258
# 1  United States of America         Americas    49833416
# 2                     India  South-East Asia    34726049
# 3                    Brazil         Americas    22201221
# 4        The United Kingdom           Europe    11097855
#
#    Cases - cumulative total  Cases - cumulative total per 100000 population  \
# 0               3489.150681                                         4018879
# 1              15055.292000                                          571461
# 2               2516.372000                                           51305
# 3              10444.713000                                           33440
# 4              16347.781000                                          436870
#
#    Cases - newly reported in last 7 days  \
# 0                              51.560179
# 1                             172.645000
# ...

# %%
df2.tail()
# Out:
#               country             Name  WHO Region  Cases - cumulative total  \
# 233  Pitcairn Islands  Western Pacific           0                       0.0
# 234      Saint Helena           Africa           0                       0.0
# 235           Tokelau  Western Pacific           0                       0.0
# 236      Turkmenistan           Europe           0                       0.0
# 237            Tuvalu  Western Pacific           0                       0.0
#
#      Cases - cumulative total per 100000 population  \
# 233                                               0
# 234                                               0
# 235                                               0
# 236                                               0
# 237                                               0
#
#      Cases - newly reported in last 7 days  \
# 233                                    0.0
# 234                                    0.0
# 235                                    0.0
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 13 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   country                                                       238 non-null    object
#  1   Name                                                          237 non-null    object
#  2   WHO Region                                                    238 non-null    int64
#  3   Cases - cumulative total                                      237 non-null    float64
#  4   Cases - cumulative total per 100000 population                238 non-null    int64
#  5   Cases - newly reported in last 7 days                         237 non-null    float64
#  6   Cases - newly reported in last 7 days per 100000 population   238 non-null    int64
# ...

# %%
df2.describe()
# Out:
#          WHO Region  Cases - cumulative total  \
# count  2.380000e+02                237.000000
# mean   2.285406e+06               6212.224606
# std    1.810009e+07               6149.957638
# min    0.000000e+00                  0.000000
# 25%    1.054650e+04                480.846000
# 50%    9.277800e+04               4985.674000
# 75%    5.753862e+05              10120.178000
# max    2.719633e+08              26595.483000
#
#        Cases - cumulative total per 100000 population  \
# count                                    2.380000e+02
# mean                                     3.377209e+04
# std                                      2.663907e+05
# min                                      0.000000e+00
# 25%                                      5.950000e+01
# 50%                                      6.215000e+02
# 75%                                      4.867000e+03
# max                                      4.018879e+06
#
#        Cases - newly reported in last 7 days  \
# ...

# %%
df2['country']
# Out:
# 0                        Global
# 1      United States of America
# 2                         India
# 3                        Brazil
# 4            The United Kingdom
#                  ...
# 233            Pitcairn Islands
# 234                Saint Helena
# 235                     Tokelau
# 236                Turkmenistan
# 237                      Tuvalu
# Name: country, Length: 238, dtype: object

# %%
df2["country"].unique()
# Out:
# array(['Global', 'United States of America', 'India', 'Brazil',
#        'The United Kingdom', 'Russian Federation', 'Turkey', 'France',
#        'Germany', 'Iran (Islamic Republic of)', 'Spain', 'Argentina',
#        'Italy', 'Colombia', 'Indonesia', 'Mexico', 'Poland', 'Ukraine',
#        'South Africa', 'Netherlands', 'Philippines', 'Malaysia',
#        'Czechia', 'Peru', 'Thailand', 'Iraq', 'Belgium', 'Canada',
#        'Romania', 'Chile', 'Japan', 'Bangladesh', 'Viet Nam', 'Israel',
#        'Pakistan', 'Serbia', 'Sweden', 'Austria', 'Hungary', 'Portugal',
#        'Switzerland', 'Kazakhstan', 'Greece', 'Jordan', 'Cuba', 'Morocco',
#        'Georgia', 'Nepal', 'Slovakia', 'United Arab Emirates', 'Bulgaria',
#        'Tunisia', 'Lebanon', 'Belarus', 'Croatia', 'Ireland', 'Guatemala',
#        'Azerbaijan', 'Denmark', 'Sri Lanka', 'Costa Rica',
#        'Bolivia (Plurinational State of)', 'Republic of Korea',
#        'Saudi Arabia', 'Ecuador', 'Myanmar', 'Lithuania', 'Panama',
# ...

# %%
#remove white spaces - amy not be needed
df2.columns = [col.strip() for col in df2.columns]
df2.columns
# Out:
# Index(['country', 'Name', 'WHO Region', 'Cases - cumulative total',
#        'Cases - cumulative total per 100000 population',
#        'Cases - newly reported in last 7 days',
#        'Cases - newly reported in last 7 days per 100000 population',
#        'Cases - newly reported in last 24 hours', 'Deaths - cumulative total',
#        'Deaths - cumulative total per 100000 population',
#        'Deaths - newly reported in last 7 days',
#        'Deaths - newly reported in last 7 days per 100000 population',
#        'Deaths - newly reported in last 24 hours'],
#       dtype='object')

# %%
df2.loc[1:4,'country']
# Out:
# 1    United States of America
# 2                       India
# 3                      Brazil
# 4          The United Kingdom
# Name: country, dtype: object

# %%
df2.country == 'Ireland'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 233    False
# 234    False
# 235    False
# 236    False
# 237    False
# Name: country, Length: 238, dtype: bool

# %%
df2[df2.country == "Ireland"]
# Out:
#     country    Name  WHO Region  Cases - cumulative total  \
# 55  Ireland  Europe      640548                 12902.724
#
#     Cases - cumulative total per 100000 population  \
# 55                                           29693
#
#     Cases - newly reported in last 7 days  \
# 55                                598.114
#
#     Cases - newly reported in last 7 days per 100000 population  \
# 55                                               4141
#
#     Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 55                                     5835                    117.536
#
#     Deaths - cumulative total per 100000 population  \
# 55                                               47
#
#     Deaths - newly reported in last 7 days  \
# 55                                   0.947
#
#     Deaths - newly reported in last 7 days per 100000 population  \
# 55                                                  0
#
#     Deaths - newly reported in last 24 hours
# ...

# %%
df2.loc[df2.country =='Ireland',['Deaths - newly reported in last 24 hours']]
# Out:
#     Deaths - newly reported in last 24 hours
# 55                                       NaN

# %%
df2.loc[df2.country =='Ireland',['Deaths - newly reported in last 24 hours']].min()
# Out:
# Deaths - newly reported in last 24 hours   NaN
# dtype: float64

# %%
df2.loc[df2.country =='Ireland',['Deaths - newly reported in last 24 hours']].max()
# Out:
# Deaths - newly reported in last 24 hours   NaN
# dtype: float64

# %%
df2.loc[df2.country =='Ireland',['Deaths - newly reported in last 24 hours']].sum()
# Out:
# Deaths - newly reported in last 24 hours    0.0
# dtype: float64

# %%
#df.New_Deaths.idxmax()  returns where new deaths were maximum in df
# as lables have changed this doesnt work
# using the column lablels below also doesn't work/ Might be due to dash?
df2.loc[df2.Deaths - newly reported in last 7 days.idxmax()
# Out:
#   File "<ipython-input-27-193ef70ba8a5>", line 4
#     df2.loc[df2.Deaths - newly reported in last 7 days.idxmax()
#                                ^
# SyntaxError: invalid syntax

# %%
df2.loc[df2.country =='Ireland',['Deaths - newly reported in last 24 hours']]

# %%
df2.loc[df2.country =='Ireland',['Cases - newly reported in last 24 hours']]
